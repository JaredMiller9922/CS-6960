# %% [markdown]
# ## Code Agent ##
# - Description: For my CodeAgent I implemented a web search tool that searches the web for a playlist of music. I also implemented a suggest board game tool that suggest a board game for the party based on the number of players in attendance. I ran out of inference api calls so I had to download and run a model locally. I also allowed the datetime module as a authorized import. I'm happy with the results for what I had to work with.
#
# Code can be seen below

# %%
# Start by logging into huggingface_hub
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Lets actually run the agent
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel, tool 

# Trying to run model locally
from smolagents import TransformersModel

# Allow time modules
import numpy as np
import time
import datetime

# Tool to suggest a board game based on the number of players
@tool
def suggest_board_games(players: int) -> str:
    """
    Suggests a board game based on the number of players.
    Args:
        players (int): The number of players that will be at the party. Possible values are:
        - Any Integer
    """
    if players == 2:
        return "Seven Wonders Duel"
    elif players == 3:
        return "Everdell"
    elif players == 4:
        return "Dominion"
    elif players >5: 
        return "Blood on The Clocktower"

# Tool to suggest a menu based on the occasion
@tool
def suggest_menu(occasion: str) -> str:
    """
    Suggests a menu based on the occasion.
    Args:
        occasion (str): The type of occasion for the party. Allowed values are:
                        - "casual": Menu for casual party.
                        - "formal": Menu for formal party.
                        - "superhero": Menu for superhero party.
                        - "custom": Custom menu.
    """
    if occasion == "casual":
        return "Pizza, snacks, and drinks."
    elif occasion == "formal":
        return "3-course dinner with wine and dessert."
    elif occasion == "superhero":
        return "Buffet with high-energy and healthy food."
    else:
        return "Custom menu for the butler."

# agent = CodeAgent(tools=[suggest_board_games, suggest_menu, DuckDuckGoSearchTool()], model = InferenceClientModel())
# agent = CodeAgent(tools=[suggest_board_games, suggest_menu, DuckDuckGoSearchTool()], model = TransformersModel("mistralai/Mistral-7B-Instruct-v0.2", device_map="auto"))
agent = CodeAgent(tools=[suggest_board_games, suggest_menu, DuckDuckGoSearchTool()], model = TransformersModel(device_map="auto"), additional_authorized_imports=['datetime'])
agent.run("Search for the best music reccomendations for a party at the Wayne's mansion. Only run a single search and provide links to a few songs in your final answer.")
agent.run("Suggest a board game based on there being 10 players")
agent.run("The party is going to be a casual occasion. Suggest a menu")
agent.run(
    """
    Alfred needs to prepare for the party. Here are the tasks:
    1. Prepare the drinks - 30 minutes
    2. Decorate the mansion - 60 minutes
    3. Set up the menu - 45 minutes
    4. Prepare the music and playlist - 45 minutes

    If we start right now, at what time will the party be ready?
    """
)
# Out:
# c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\smolagents\models.py:933: FutureWarning: The 'model_id' parameter will be required in version 2.0.0. Please update your code to pass this parameter to avoid future errors. For now, it defaults to 'HuggingFaceTB/SmolLM2-1.7B-Instruct'.
#   warnings.warn(
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music reccomendations for a party at the Wayne's mansion. Only run a single search and      │
# │ provide links to a few songs in your final answer.                                                              │
# │                                                                                                                 │
# ╰─ TransformersModel - HuggingFaceTB/SmolLM2-1.7B-Instruct ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   for song in ["Bohemian Rhapsody", "Stairway to Heaven", "Imagine", "Hotel California", "Bohemian Rhapsody
#   (Live)"]:
#       print(f"Song: {song}")
#       print(f"Link: https://www.youtube.com/watch?v={song}")
#       print("\n" + "="*80 + "\n")  # Print separator between songs
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Song: Bohemian Rhapsody
# Link: https://www.youtube.com/watch?v=Bohemian Rhapsody
#
# ================================================================================
#
# Song: Stairway to Heaven
# Link: https://www.youtube.com/watch?v=Stairway to Heaven
#
# ================================================================================
#
# Song: Imagine
# Link: https://www.youtube.com/watch?v=Imagine
#
# ================================================================================
#
# Song: Hotel California
# Link: https://www.youtube.com/watch?v=Hotel California
#
# ================================================================================
#
# Song: Bohemian Rhapsody (Live)
# Link: https://www.youtube.com/watch?v=Bohemian Rhapsody (Live)
#
# ================================================================================
#
#
# Out: None
# [Step 1: Duration 90.69 seconds| Input tokens: 2,525 | Output tokens: 127]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer(["Bohemian Rhapsody", "Stairway to Heaven", "Imagine", "Hotel California", "Bohemian Rhapsody
#   (Live)"])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: ['Bohemian Rhapsody', 'Stairway to Heaven', 'Imagine', 'Hotel California', 'Bohemian Rhapsody
# (Live)']
# [Step 2: Duration 72.61 seconds| Input tokens: 5,506 | Output tokens: 197]
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Suggest a board game based on there being 10 players                                                            │
# │                                                                                                                 │
# ╰─ TransformersModel - HuggingFaceTB/SmolLM2-1.7B-Instruct ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   penguin_board_game = suggest_board_games(10)
#   final_answer(penguin_board_game)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Blood on The Clocktower
# [Step 1: Duration 56.29 seconds| Input tokens: 2,501 | Output tokens: 64]
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ The party is going to be a casual occasion. Suggest a menu                                                      │
# │                                                                                                                 │
# ╰─ TransformersModel - HuggingFaceTB/SmolLM2-1.7B-Instruct ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   menu = suggest_menu("casual")
#   print(menu)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Pizza, snacks, and drinks.
#
# Out: None
# [Step 1: Duration 48.79 seconds| Input tokens: 2,502 | Output tokens: 45]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer(menu)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Pizza, snacks, and drinks.
# [Step 2: Duration 47.98 seconds| Input tokens: 5,139 | Output tokens: 83]
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Alfred needs to prepare for the party. Here are the tasks:                                                      │
# │     1. Prepare the drinks - 30 minutes                                                                          │
# │     2. Decorate the mansion - 60 minutes                                                                        │
# │     3. Set up the menu - 45 minutes                                                                             │
# │     4. Prepare the music and playlist - 45 minutes                                                              │
# │                                                                                                                 │
# │     If we start right now, at what time will the party be ready?                                                │
# │                                                                                                                 │
# ╰─ TransformersModel - HuggingFaceTB/SmolLM2-1.7B-Instruct ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   total_time = 30 + 60 + 45 + 45
#   party_time = total_time + 30
#   final_answer(party_time)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 210
# [Step 1: Duration 65.80 seconds| Input tokens: 2,567 | Output tokens: 72]
# 210

# %% [markdown]
# ## Tool Calling Agent ##
# - Description: I implemented the same tools that my code agent implemented here. I had to adjust a few of the agent prompts to make everything work as expected. Suprisingly, even though the model said this wouldn't happen, the tool agent worked significantly faster and better than the code agent. I think this is because I had to run a worse model locally than the tutorial expected and it wasn't all that great with writing code. One important thing to note here is that final task of adding up times didn't work on the tool calling agent. This is expected behavior because we didn't give the agent the option to do this. So I think that even though the tool agent was quicker and preformed better because of how much less general it is, a code agent will almost always be better.
#
# Code Can Be Seen Below

# %%
# Lets actually run the agent
from smolagents import ToolCallingAgent, DuckDuckGoSearchTool, tool 

# Trying to run model locally
from smolagents import TransformersModel

# Tool to suggest a board game based on the number of players
@tool
def suggest_board_games(players: int) -> str:
    """
    Suggests a board game based on the number of players.
    Args:
        players (int): The number of players that will be at the party. Possible values are:
        - Any Integer
    """
    if players == 2:
        return "Seven Wonders Duel"
    elif players == 3:
        return "Everdell"
    elif players == 4:
        return "Dominion"
    elif players >5: 
        return "Blood on The Clocktower"

# Tool to suggest a menu based on the occasion
@tool
def suggest_menu(occasion: str) -> str:
    """
    Suggests a menu based on the occasion.
    Args:
        occasion (str): The type of occasion for the party. Allowed values are:
                        - "casual": Menu for casual party.
                        - "formal": Menu for formal party.
                        - "superhero": Menu for superhero party.
                        - "custom": Custom menu.
    """
    if occasion == "casual":
        return "Pizza, snacks, and drinks."
    elif occasion == "formal":
        return "3-course dinner with wine and dessert."
    elif occasion == "superhero":
        return "Buffet with high-energy and healthy food."
    else:
        return "Custom menu for the butler."

# agent = CodeAgent(tools=[suggest_board_games, suggest_menu, DuckDuckGoSearchTool()], model = InferenceClientModel())
# agent = CodeAgent(tools=[suggest_board_games, suggest_menu, DuckDuckGoSearchTool()], model = TransformersModel("mistralai/Mistral-7B-Instruct-v0.2", device_map="auto"))
agent = ToolCallingAgent(tools=[suggest_board_games, suggest_menu, DuckDuckGoSearchTool()], model = TransformersModel(device_map="auto"))
agent.run("Search for the best music reccomendations for a party at the Wayne's mansion. Only run a single search and provide links to a few songs in your final answer.")
agent.run("Suggest a board game based on there being 10 players. Pass in the number 10 to the tool as an integer")
agent.run("The party is going to be a casual occasion. Suggest a menu")
agent.run(
  """
  Alfred needs to prepare for the party. Here are the tasks:
  1. Prepare the drinks - 30 minutes
  2. Decorate the mansion - 60 minutes
  3. Set up the menu - 45 minutes
  4. Prepare the music and playlist - 45 minutes

  If we start right now, at what time will the party be ready?
  """
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music reccomendations for a party at the Wayne's mansion. Only run a single search and      │
# │ provide links to a few songs in your final answer.                                                              │
# │                                                                                                                 │
# ╰─ TransformersModel - HuggingFaceTB/SmolLM2-1.7B-Instruct ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'web_search' with arguments: Music recommendations for a party at the Wayne's mansion             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: ## Search Results
#
# |The Wayne Mansion](https://www.luckysavannah.com/vacation-rentals/wayne-mansion)
# Guests will enjoy having an additional dining space at the large kitchen island that provides seating for 6. ...
# the best stay at the Wayne mansion ! ...
#
# |Wayne Tree Manor - Banquet Halls - Wayne, MI -
# WeddingWire](https://www.weddingwire.com/biz/wayne-tree-manor-wayne/cc335ebd7347d092.html)
# Facilities and Capacity Wayne Tree Manor offers four spaces to choose from for your “I do.” The Banquet Center
# holds three different rooms, Pine ...
#
# |Wayne Foster Music & Entertainment Reviews - Carlsbad, CA -
# 17](https://www.weddingwire.com/reviews/wayne-foster-music-entertainment-carlsbad/588003f73bdc1398.html)
# Wayne Foster is amazing! We had a 7-person band play at our wedding and they were ON FIRE! Instead of taking the
# expected break between sets, the band ...
#
# |Wedding Party Entrance Songs to Get the Party Started -
# The](https://mansiononmainstreet.com/wedding-party-entrance-songs-to-get-the-party-started/)
# You can serve delicious food at a gorgeous venue, but the music is what really takes a party from mediocre to
# unforgettable .
#
# |36 Best Party Halls for Rent in Detroit, MI | Peerspace](https://www.peerspace.com/venues/detroit--mi/party-hall)
# Welcome to our space, an extraordinary venue for meetings and events in the heart of downtown Detroit. ... an
# expansive 8,500 sqft event venue in the ...
#
# |beatrice_otter | Entries tagged with meta](https://beatrice-otter.dreamwidth.org/tag/meta)
# I was re-reading some old MCU fic, and in the fic Steve says that Bucky was named for President Buchanan. ...
# Steve' s middle name is " Grant ...
#
# |Wedding & Event Venues that Recommend Gemini DJs in NY/NJ](https://geminidjs.com/nj-wedding-venues/)
# Gemini DJs offers the latest and greatest in music , lighting, tv’ s photo booths and more! ... at 973-686-1003 to
# schedule time to visit our studio ...
#
# |Building Agents That Use Code - Hugging Face Agents
# Course](https://huggingface.co/learn/agents-course/unit2/smolagents/code_agents)
# ... smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel agent =
# CodeAgent(tools=|DuckDuckGoSearchTool()], ...
#
# |Having problem running qwen2:7b locally.
# Getting](https://discuss.huggingface.co/t/having-problem-running-qwen2-7b-locally-getting-agentgenerationerror-erro
# r-in-generating-model-output/159497)
# ... smolagents import CodeAgent, DuckDuckGoSearchTool, LiteLLMModel from smolagents import LiteLLMModel model =
# LiteLLMModel( ...
#
# |Board of Directors – Sands Point
# Preserve](https://www.sandspointpreserveconservancy.org/about/board-of-directors/)
# Adler Georgia DeYoung Adam Hanft Brian Herrington Dilia Kamensky Chiara Trento Mai Carol Rossettie Jean-Marie
# Posner Anita Sethi Jane Stern Frank C.
# [Step 1: Duration 29.67 seconds| Input tokens: 1,189 | Output tokens: 35]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'final_answer' with arguments: ['https://www.luckysavannah.com/vacation-rentals/wayne-mansion',   │
# │ 'https://www.wayne-tree-manor.com/banquet-halls',                                                               │
# │ 'https://www.weddingwire.com/reviews/wayne-foster-music-entertainment-carlsbad',                                │
# │ 'https://mansiononmainstreet.com/wedding-party-entrance-songs-to-get-the-party-started/',                       │
# │ 'https://geminidjs.com/nj-wedding-venues/',                                                                     │
# │ 'https://huggingface.co/learn/agents-course/unit2/smolagents/code_agents',                                      │
# │ 'https://huggingface.co/learn/agents-course/unit2/smolagents/code_agents',                                      │
# │ 'https://www.sandspointpreserveconservancy.org/about/board-of-directors/']                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: |'https://www.luckysavannah.com/vacation-rentals/wayne-mansion',
# 'https://www.wayne-tree-manor.com/banquet-halls',
# 'https://www.weddingwire.com/reviews/wayne-foster-music-entertainment-carlsbad',
# 'https://mansiononmainstreet.com/wedding-party-entrance-songs-to-get-the-party-started/',
# 'https://geminidjs.com/nj-wedding-venues/',
# 'https://huggingface.co/learn/agents-course/unit2/smolagents/code_agents',
# 'https://huggingface.co/learn/agents-course/unit2/smolagents/code_agents',
# 'https://www.sandspointpreserveconservancy.org/about/board-of-directors/']
# Final answer: ['https://www.luckysavannah.com/vacation-rentals/wayne-mansion',
# 'https://www.wayne-tree-manor.com/banquet-halls',
# 'https://www.weddingwire.com/reviews/wayne-foster-music-entertainment-carlsbad',
# 'https://mansiononmainstreet.com/wedding-party-entrance-songs-to-get-the-party-started/',
# 'https://geminidjs.com/nj-wedding-venues/',
# 'https://huggingface.co/learn/agents-course/unit2/smolagents/code_agents',
# 'https://huggingface.co/learn/agents-course/unit2/smolagents/code_agents',
# 'https://www.sandspointpreserveconservancy.org/about/board-of-directors/']
# [Step 2: Duration 133.02 seconds| Input tokens: 3,342 | Output tokens: 263]
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Suggest a board game based on there being 10 players. Pass in the number 10 to the tool as an integer           │
# │                                                                                                                 │
# ╰─ TransformersModel - HuggingFaceTB/SmolLM2-1.7B-Instruct ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'suggest_board_games' with arguments: {'players': 10}                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: Blood on The Clocktower
# [Step 1: Duration 24.05 seconds| Input tokens: 1,179 | Output tokens: 29]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'final_answer' with arguments: {'answer': 'Blood on The Clocktower'}                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: Blood on The Clocktower
# Final answer: Blood on The Clocktower
# [Step 2: Duration 25.40 seconds| Input tokens: 2,482 | Output tokens: 59]
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ The party is going to be a casual occasion. Suggest a menu                                                      │
# │                                                                                                                 │
# ╰─ TransformersModel - HuggingFaceTB/SmolLM2-1.7B-Instruct ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'suggest_menu' with arguments: {'occasion': 'casual'}                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: Pizza, snacks, and drinks.
# [Step 1: Duration 23.78 seconds| Input tokens: 1,166 | Output tokens: 31]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'final_answer' with arguments: {'answer': 'Pizza, snacks, and drinks'}                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: Pizza, snacks, and drinks
# Final answer: Pizza, snacks, and drinks
# [Step 2: Duration 26.19 seconds| Input tokens: 2,460 | Output tokens: 63]
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Alfred needs to prepare for the party. Here are the tasks:                                                      │
# │   1. Prepare the drinks - 30 minutes                                                                            │
# │   2. Decorate the mansion - 60 minutes                                                                          │
# │   3. Set up the menu - 45 minutes                                                                               │
# │   4. Prepare the music and playlist - 45 minutes                                                                │
# │                                                                                                                 │
# │   If we start right now, at what time will the party be ready?                                                  │
# │                                                                                                                 │
# ╰─ TransformersModel - HuggingFaceTB/SmolLM2-1.7B-Instruct ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error while parsing tool call from model output: The model output does not contain any JSON blob.
# [Step 1: Duration 128.59 seconds| Input tokens: 1,231 | Output tokens: 251]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [Step 2: Duration 66.77 seconds]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 52
#      50 agent.run("Suggest a board game based on there being 10 players. Pass in the number 10 to the tool as an integer")
#      51 agent.run("The party is going to be a casual occasion. Suggest a menu")
# ---> 52 agent.run(
#      53   """
#      54   Alfred needs to prepare for the party. Here are the tasks:
#      55   1. Prepare the drinks - 30 minutes
#      56   2. Decorate the mansion - 60 minutes
#      57   3. Set up the menu - 45 minutes
#      58   4. Prepare the music and playlist - 45 minutes
#      59
#      60   If we start right now, at what time will the party be ready?
#      61   """
#      62 )
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\smolagents\agents.py:498, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps, return_full_result)
#     495     return self._run_stream(task=self.task, max_steps=max_steps, images=images)
#     497 run_start_time = time.time()
# --> 498 steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     500 # Outputs are returned only at the end. We only look at the last step.
#     501 assert isinstance(steps[-1], FinalAnswerStep)
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\smolagents\agents.py:577, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     575 self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     576 try:
# --> 577     for output in self._step_stream(action_step):
#     578         # Yield all
#     579         yield output
#     581         if isinstance(output, ActionOutput) and output.is_final_answer:
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\smolagents\agents.py:1293, in ToolCallingAgent._step_stream(self, memory_step)
#    1291     chat_message = agglomerate_stream_deltas(chat_message_stream_deltas)
#    1292 else:
# -> 1293     chat_message: ChatMessage = self.model.generate(
#    1294         input_messages,
#    1295         stop_sequences=["Observation:", "Calling tools:"],
#    1296         tools_to_call_from=self.tools_and_managed_agents,
#    1297     )
#    1298     self.logger.log_markdown(
#    1299         content=str(chat_message.content or chat_message.raw or ""),
#    1300         title="Output message of the LLM:",
#    1301         level=LogLevel.DEBUG,
#    1302     )
#    1304 # Record model output
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\smolagents\models.py:1069, in TransformersModel.generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1062 generation_kwargs = self._prepare_completion_args(
#    1063     messages=messages,
#    1064     stop_sequences=stop_sequences,
#    1065     tools_to_call_from=tools_to_call_from,
#    1066     **kwargs,
#    1067 )
#    1068 count_prompt_tokens = generation_kwargs["inputs"].shape[1]  # type: ignore
# -> 1069 out = self.model.generate(
#    1070     **generation_kwargs,
#    1071 )
#    1072 generated_tokens = out[0, count_prompt_tokens:]
#    1073 if hasattr(self, "processor"):
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\transformers\generation\utils.py:2566, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2563 model_kwargs["use_cache"] = generation_config.use_cache
#    2565 # 9. Call generation mode
# -> 2566 result = decoding_method(
#    2567     self,
#    2568     input_ids,
#    2569     logits_processor=prepared_logits_processor,
#    2570     stopping_criteria=prepared_stopping_criteria,
#    2571     generation_config=generation_config,
#    2572     **generation_mode_kwargs,
#    2573     **model_kwargs,
#    2574 )
#    2576 # Convert to legacy cache format if requested
#    2577 if (
#    2578     generation_config.return_legacy_cache is True
#    2579     and hasattr(result, "past_key_values")
#    2580     and getattr(result.past_key_values, "to_legacy_cache") is not None
#    2581 ):
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\transformers\generation\utils.py:2789, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2787     is_prefill = False
#    2788 else:
# -> 2789     outputs = model_forward(**model_inputs, return_dict=True)
#    2791 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    2792 model_kwargs = self._update_model_kwargs_for_generation(
#    2793     outputs,
#    2794     model_kwargs,
#    2795     is_encoder_decoder=self.config.is_encoder_decoder,
#    2796 )
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\transformers\utils\generic.py:918, in can_return_tuple.<locals>.wrapper(self, *args, **kwargs)
#     916 if return_dict_passed is not None:
#     917     return_dict = return_dict_passed
# --> 918 output = func(self, *args, **kwargs)
#     919 if not return_dict and not isinstance(output, tuple):
#     920     output = output.to_tuple()
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\transformers\models\llama\modeling_llama.py:459, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     427 @can_return_tuple
#     428 @auto_docstring
#     429 def forward(
#    (...)    440     **kwargs: Unpack[TransformersKwargs],
#     441 ) -> CausalLMOutputWithPast:
#     442     r"""
#     443     Example:
#     444
#    (...)    457     "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     458     ```"""
# --> 459     outputs: BaseModelOutputWithPast = self.model(
#     460         input_ids=input_ids,
#     461         attention_mask=attention_mask,
#     462         position_ids=position_ids,
#     463         past_key_values=past_key_values,
#     464         inputs_embeds=inputs_embeds,
#     465         use_cache=use_cache,
#     466         cache_position=cache_position,
#     467         **kwargs,
#     468     )
#     470     hidden_states = outputs.last_hidden_state
#     471     # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\transformers\utils\generic.py:1072, in check_model_inputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#    1069                 monkey_patched_layers.append((module, original_forward))
#    1071 try:
# -> 1072     outputs = func(self, *args, **kwargs)
#    1073 except TypeError as original_exception:
#    1074     # If we get a TypeError, it's possible that the model is not receiving the recordable kwargs correctly.
#    1075     # Get a TypeError even after removing the recordable kwargs -> re-raise the original exception
#    1076     # Otherwise -> we're probably missing `**kwargs` in the decorated function
#    1077     kwargs_without_recordable = {k: v for k, v in kwargs.items() if k not in recordable_keys}
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\transformers\models\llama\modeling_llama.py:395, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, cache_position, use_cache, **kwargs)
#     392 position_embeddings = self.rotary_emb(hidden_states, position_ids)
#     394 for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 395     hidden_states = decoder_layer(
#     396         hidden_states,
#     397         attention_mask=causal_mask,
#     398         position_ids=position_ids,
#     399         past_key_values=past_key_values,
#     400         cache_position=cache_position,
#     401         position_embeddings=position_embeddings,
#     402         **kwargs,
#     403     )
#     405 hidden_states = self.norm(hidden_states)
#     406 return BaseModelOutputWithPast(
#     407     last_hidden_state=hidden_states,
#     408     past_key_values=past_key_values,
#     409 )
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\transformers\modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\transformers\models\llama\modeling_llama.py:309, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, cache_position, position_embeddings, **kwargs)
#     307 residual = hidden_states
#     308 hidden_states = self.post_attention_layernorm(hidden_states)
# --> 309 hidden_states = self.mlp(hidden_states)
#     310 hidden_states = residual + hidden_states
#     311 return hidden_states
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\transformers\models\llama\modeling_llama.py:155, in LlamaMLP.forward(self, x)
#     154 def forward(self, x):
# --> 155     down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#     156     return down_proj
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\jared\anaconda3\envs\CS-6960\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
